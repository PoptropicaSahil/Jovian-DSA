# %% [markdown]
# # Recursive binary search

# %%
def binarySearch(arr, l, r, x):

	# Check base case
	if r >= l:

		mid = l + (r - l) // 2
		if arr[mid] == x:
			return mid
		elif arr[mid] > x:
			return binarySearch(arr, l, mid-1, x)
		else:
			return binarySearch(arr, mid + 1, r, x)

	else:
		return -1


# Driver Code
arr = [2, 3, 4, 10, 10, 40]
x = 10

# Function call
result = binarySearch(arr, 0, len(arr)-1, x)
result
# Out:
# 4

# %%
arr=[]
x=5
binarySearch(arr, None, None, x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-f94d37e840f9> in <module>()
#       1 arr=[]
#       2 x=5
# ----> 3 binarySearch(arr, None, None, x)
#
# <ipython-input-6-66253d122556> in binarySearch(arr, l, r, x)
#       2
#       3         # Check base case
# ----> 4         if r >= l:
#       5
#       6                 mid = l + (r - l) // 2
#
# TypeError: '>=' not supported between instances of 'NoneType' and 'NoneType'

# %%
if result != -1:
	print("Element is present at index % d" % result)
else:
	print("Element is not present in array")
# Out:
# Element is present at index  3

# %%
# Driver Code
arr = [2, 3, 4, 4, 10, 40]
x = 4

# Function call
result = binarySearch(arr, 0, len(arr)-1, x)
print(result)
# Out:
# 2

# %% [markdown]
# # Iterative Bineary Search

# %%
def binarySearch(arr, l, r, x):
	while l <= r:
		mid = l + (r - l) // 2

		if arr[mid] == x:
			return mid

		elif arr[mid] < x:
			l = mid + 1

		else:
			r = mid - 1

	return -1

# %%
# Driver Code
arr = [2, 3, 4, 10, 40]
x = 10

# Function call
result = binarySearch(arr, 0, len(arr)-1, x)
print(result)

if result != -1:
	print("Element is present at index % d" % result)
else:
	print("Element is not present in array")
# Out:
# 3
# Element is present at index  3

# %%
# Leetcode solution

def binary_search(nums, target):
    left, right = 0, len(nums)-1
    
    while left <= right:
        mid = left + (right-left) // 2
        print(f'left {left}, right {right}, mid {mid}')

        if nums[mid] == target:
            return mid
        
        if target < nums[mid]:
                right = mid-1
        else:
            left = mid + 1
        print(f'\tnow left {left}, right {right}, mid {mid}, nums_mid {nums[mid]}')
    
    return -1

# %%
binary_search(nums=[5,3,2,1,-1,-1,-5], target = -1)
# Out:
# left 0, right 6, mid 3
# 	now left 0, right 2, mid 3, nums_mid 1
# left 0, right 2, mid 1
# 	now left 0, right 0, mid 1, nums_mid 3
# left 0, right 0, mid 0
# 	now left 0, right -1, mid 0, nums_mid 5
# -1
